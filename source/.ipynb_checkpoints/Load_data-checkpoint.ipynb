# %%
import numpy as np
import h5py

# %% [markdown]
# We load the data from the training runs. Put here for better visualization in Post_Process

# %%
def nz(x):
    x = x[np.nonzero(x)]
    return x

#(i) - (ii)

hf       = h5py.File('./data/Lorenz_Rec_x_[0, 2]_100_10050.h5','r')
l_y_100  = np.array(hf.get('loss'))
tl_y_100 = np.array(hf.get('true_loss'))
W_y_100  = np.array(hf.get('Wout'))
hf.close()

hf       = h5py.File('./data/Lorenz_Rec_x_[0, 2]_100_10050.h5','w')
hf.create_dataset('Wout'     ,data=W_y_100)
hf.create_dataset('loss'     ,data=nz(l_y_100))
hf.create_dataset('true_loss',data=nz(tl_y_100))
hf.close()

hf       = h5py.File('./data/Lorenz_Rec_x_[0, 1]_100_10050.h5','r')
l_z_100  = np.array(hf.get('loss'))
tl_z_100 = np.array(hf.get('true_loss'))
W_z_100  = np.array(hf.get('Wout'))
hf.close()

hf       = h5py.File('./data/Lorenz_Rec_x_[0, 1]_100_10050.h5','w')
hf.create_dataset('Wout'     ,data=W_z_100)
hf.create_dataset('loss'     ,data=nz(l_z_100))
hf.create_dataset('true_loss',data=nz(tl_z_100))
hf.close()

hf       = h5py.File('./data/Lorenz_Rec_x_[0, 2]_200_10050.h5','r')
l_y_200  = np.array(hf.get('loss'))
tl_y_200 = np.array(hf.get('true_loss'))
W_y_200  = np.array(hf.get('Wout'))
hf.close()

hf       = h5py.File('./data/Lorenz_Rec_x_[0, 2]_200_10050.h5','w')
hf.create_dataset('Wout'     ,data=W_y_200)
hf.create_dataset('loss'     ,data=nz(l_y_200))
hf.create_dataset('true_loss',data=nz(tl_y_200))
hf.close()

hf       = h5py.File('./data/Lorenz_Rec_x_[0, 1]_200_10050.h5','r')
l_z_200  = np.array(hf.get('loss'))
tl_z_200 = np.array(hf.get('true_loss'))
W_z_200  = np.array(hf.get('Wout'))
hf.close()

hf       = h5py.File('./data/Lorenz_Rec_x_[0, 1]_200_10050.h5','w')
hf.create_dataset('Wout'     ,data=W_z_200)
hf.create_dataset('loss'     ,data=nz(l_z_200))
hf.create_dataset('true_loss',data=nz(tl_z_200))
hf.close()

hf       = h5py.File('./data/Lorenz_Rec_x_[0, 2]_500_10050.h5','r')
l_y_500  = np.array(hf.get('loss'))
tl_y_500 = np.array(hf.get('true_loss'))
W_y_500  = np.array(hf.get('Wout'))
hf.close()

hf       = h5py.File('./data/Lorenz_Rec_x_[0, 2]_500_10050.h5','w')
hf.create_dataset('Wout'     ,data=W_y_500)
hf.create_dataset('loss'     ,data=nz(l_y_500))
hf.create_dataset('true_loss',data=nz(tl_y_500))
hf.close()

hf       = h5py.File('./data/Lorenz_Rec_x_[0, 1]_500_10050.h5','r')
l_z_500  = np.array(hf.get('loss'))
tl_z_500 = np.array(hf.get('true_loss'))
W_z_500  = np.array(hf.get('Wout'))
hf.close()

hf       = h5py.File('./data/Lorenz_Rec_x_[0, 1]_500_10050.h5','w')
hf.create_dataset('Wout'     ,data=W_z_500)
hf.create_dataset('loss'     ,data=nz(l_z_500))
hf.create_dataset('true_loss',data=nz(tl_z_500))
hf.close()

hf       = h5py.File('./data/Lorenz_Rec_x_[0, 2]_750_10050.h5','r')
l_y_750  = np.array(hf.get('loss'))
tl_y_750 = np.array(hf.get('true_loss'))
W_y_750  = np.array(hf.get('Wout'))
hf.close()

hf       = h5py.File('./data/Lorenz_Rec_x_[0, 2]_750_10050.h5','w')
hf.create_dataset('Wout'     ,data=W_y_750)
hf.create_dataset('loss'     ,data=nz(l_y_750))
hf.create_dataset('true_loss',data=nz(tl_y_750))
hf.close()

hf       = h5py.File('./data/Lorenz_Rec_x_[0, 1]_750_10050.h5','r')
l_z_750  = np.array(hf.get('loss'))
tl_z_750 = np.array(hf.get('true_loss'))
W_z_750  = np.array(hf.get('Wout'))
hf.close()

hf       = h5py.File('./data/Lorenz_Rec_x_[0, 1]_750_10050.h5','w')
hf.create_dataset('Wout'     ,data=W_z_750)
hf.create_dataset('loss'     ,data=nz(l_z_750))
hf.create_dataset('true_loss',data=nz(tl_z_750))
hf.close()

hf       = h5py.File('./data/Lorenz_Rec_x_[0, 2]_1000_10050.h5','r')
l_y_1000  = np.array(hf.get('loss'))
tl_y_1000 = np.array(hf.get('true_loss'))
W_y_1000  = np.array(hf.get('Wout'))
hf.close()

hf       = h5py.File('./data/Lorenz_Rec_x_[0, 2]_1000_10050.h5','w')
hf.create_dataset('Wout'     ,data=W_y_1000)
hf.create_dataset('loss'     ,data=nz(l_y_1000))
hf.create_dataset('true_loss',data=nz(tl_y_1000))
hf.close()

hf       = h5py.File('./data/Lorenz_Rec_x_[0, 1]_1000_10050.h5','r')
l_z_1000  = np.array(hf.get('loss'))
tl_z_1000 = np.array(hf.get('true_loss'))
W_z_1000  = np.array(hf.get('Wout'))
hf.close()

hf       = h5py.File('./data/Lorenz_Rec_x_[0, 1]_1000_10050.h5','w')
hf.create_dataset('Wout'     ,data=W_z_1000)
hf.create_dataset('loss'     ,data=nz(l_z_1000))
hf.create_dataset('true_loss',data=nz(tl_z_1000))
hf.close()

hf       = h5py.File('./data/Lorenz_Rec_x_[0, 2]_100_10050_FE.h5','r')
l_y_100F  = np.array(hf.get('loss'))
tl_y_100F = np.array(hf.get('true_loss'))
W_y_100F  = np.array(hf.get('Wout'))
hf.close()

hf       = h5py.File('./data/Lorenz_Rec_x_[0, 2]_100_10050_FE.h5','w')
hf.create_dataset('Wout'     ,data=W_y_100F)
hf.create_dataset('loss'     ,data=nz(l_y_100F))
hf.create_dataset('true_loss',data=nz(tl_y_100F))
hf.close()

hf       = h5py.File('./data/Lorenz_Rec_x_[0, 1]_100_10050_FE.h5','r')
l_z_100F  = np.array(hf.get('loss'))
tl_z_100F = np.array(hf.get('true_loss'))
W_z_100F  = np.array(hf.get('Wout'))
hf.close()

hf       = h5py.File('./data/Lorenz_Rec_x_[0, 1]_100_10050_FE.h5','w')
hf.create_dataset('Wout'     ,data=W_z_100F)
hf.create_dataset('loss'     ,data=nz(l_z_100F))
hf.create_dataset('true_loss',data=nz(tl_z_100F))
hf.close()

hf       = h5py.File('./data/Lorenz_Rec_x_[0, 2]_200_10050_FE.h5','r')
l_y_200F  = np.array(hf.get('loss'))
tl_y_200F = np.array(hf.get('true_loss'))
W_y_200F  = np.array(hf.get('Wout'))
hf.close()

hf       = h5py.File('./data/Lorenz_Rec_x_[0, 2]_200_10050_FE.h5','w')
hf.create_dataset('Wout'     ,data=W_y_200F)
hf.create_dataset('loss'     ,data=nz(l_y_200F))
hf.create_dataset('true_loss',data=nz(tl_y_200F))
hf.close()

hf       = h5py.File('./data/Lorenz_Rec_x_[0, 1]_200_10050_FE.h5','r')
l_z_200F  = np.array(hf.get('loss'))
tl_z_200F = np.array(hf.get('true_loss'))
W_z_200F  = np.array(hf.get('Wout'))
hf.close()

hf       = h5py.File('./data/Lorenz_Rec_x_[0, 1]_200_10050_FE.h5','w')
hf.create_dataset('Wout'     ,data=W_z_200F)
hf.create_dataset('loss'     ,data=nz(l_z_200F))
hf.create_dataset('true_loss',data=nz(tl_z_200F))
hf.close()

hf       = h5py.File('./data/Lorenz_Rec_x_[0, 2]_500_10050_FE.h5','r')
l_y_500F  = np.array(hf.get('loss'))
tl_y_500F = np.array(hf.get('true_loss'))
W_y_500F  = np.array(hf.get('Wout'))
hf.close()

hf       = h5py.File('./data/Lorenz_Rec_x_[0, 2]_500_10050_FE.h5','w')
hf.create_dataset('Wout'     ,data=W_y_500F)
hf.create_dataset('loss'     ,data=nz(l_y_500F))
hf.create_dataset('true_loss',data=nz(tl_y_500F))
hf.close()

hf       = h5py.File('./data/Lorenz_Rec_x_[0, 1]_500_10050_FE.h5','r')
l_z_500F  = np.array(hf.get('loss'))
tl_z_500F = np.array(hf.get('true_loss'))
W_z_500F  = np.array(hf.get('Wout'))
hf.close()

hf       = h5py.File('./data/Lorenz_Rec_x_[0, 1]_500_10050_FE.h5','w')
hf.create_dataset('Wout'     ,data=W_z_500F)
hf.create_dataset('loss'     ,data=nz(l_z_500F))
hf.create_dataset('true_loss',data=nz(tl_z_500F))
hf.close()

hf       = h5py.File('./data/Lorenz_Rec_x_[0, 2]_750_10050_FE.h5','r')
l_y_750F  = np.array(hf.get('loss'))
tl_y_750F = np.array(hf.get('true_loss'))
W_y_750F  = np.array(hf.get('Wout'))
hf.close()

hf       = h5py.File('./data/Lorenz_Rec_x_[0, 2]_750_10050_FE.h5','w')
hf.create_dataset('Wout'     ,data=W_y_750F)
hf.create_dataset('loss'     ,data=nz(l_y_750F))
hf.create_dataset('true_loss',data=nz(tl_y_750F))
hf.close()

hf       = h5py.File('./data/Lorenz_Rec_x_[0, 1]_750_10050_FE.h5','r')
l_z_750F  = np.array(hf.get('loss'))
tl_z_750F = np.array(hf.get('true_loss'))
W_z_750F  = np.array(hf.get('Wout'))
hf.close()

hf       = h5py.File('./data/Lorenz_Rec_x_[0, 1]_750_10050_FE.h5','w')
hf.create_dataset('Wout'     ,data=W_z_750F)
hf.create_dataset('loss'     ,data=nz(l_z_750F))
hf.create_dataset('true_loss',data=nz(tl_z_750F))
hf.close()

hf       = h5py.File('./data/Lorenz_Rec_x_[0, 2]_1000_10050_FE.h5','r')
l_y_1000F  = np.array(hf.get('loss'))
tl_y_1000F = np.array(hf.get('true_loss'))
W_y_1000F  = np.array(hf.get('Wout'))
hf.close()

hf       = h5py.File('./data/Lorenz_Rec_x_[0, 2]_1000_10050_FE.h5','w')
hf.create_dataset('Wout'     ,data=W_y_1000F)
hf.create_dataset('loss'     ,data=nz(l_y_1000F))
hf.create_dataset('true_loss',data=nz(tl_y_1000F))
hf.close()

hf       = h5py.File('./data/Lorenz_Rec_x_[0, 1]_1000_10050_FE.h5','r')
l_z_1000F  = np.array(hf.get('loss'))
tl_z_1000F = np.array(hf.get('true_loss'))
W_z_1000F  = np.array(hf.get('Wout'))
hf.close()

hf       = h5py.File('./data/Lorenz_Rec_x_[0, 1]_1000_10050_FE.h5','w')
hf.create_dataset('Wout'     ,data=W_z_1000F)
hf.create_dataset('loss'     ,data=nz(l_z_1000F))
hf.create_dataset('true_loss',data=nz(tl_z_1000F))
hf.close()

## (iii)

hf       = h5py.File('./data/Lorenz_Rec_x_[0]_100_10050.h5','r')
l_yz_100  = np.array(hf.get('loss'))
tl_yz_100 = np.array(hf.get('true_loss'))
W_yz_100  = np.array(hf.get('Wout'))
hf.close()

hf       = h5py.File('./data/Lorenz_Rec_x_[0]_100_10050.h5','w')
hf.create_dataset('Wout'     ,data=W_yz_100)
hf.create_dataset('loss'     ,data=nz(l_yz_100))
hf.create_dataset('true_loss',data=nz(tl_yz_100))
hf.close()

hf       = h5py.File('./data/Lorenz_Rec_x_[0]_200_10050.h5','r')
l_yz_200  = np.array(hf.get('loss'))
tl_yz_200 = np.array(hf.get('true_loss'))
W_yz_200  = np.array(hf.get('Wout'))
hf.close()

hf       = h5py.File('./data/Lorenz_Rec_x_[0]_200_10050.h5','w')
hf.create_dataset('Wout'     ,data=W_yz_200)
hf.create_dataset('loss'     ,data=nz(l_yz_200))
hf.create_dataset('true_loss',data=nz(tl_yz_200))
hf.close()

hf       = h5py.File('./data/Lorenz_Rec_x_[0]_500_10050.h5','r')
l_yz_500  = np.array(hf.get('loss'))
tl_yz_500 = np.array(hf.get('true_loss'))
W_yz_500  = np.array(hf.get('Wout'))
hf.close()

hf       = h5py.File('./data/Lorenz_Rec_x_[0]_500_10050.h5','w')
hf.create_dataset('Wout'     ,data=W_yz_500)
hf.create_dataset('loss'     ,data=nz(l_yz_500))
hf.create_dataset('true_loss',data=nz(tl_yz_500))
hf.close()

hf       = h5py.File('./data/Lorenz_Rec_x_[0]_750_10050.h5','r')
l_yz_750  = np.array(hf.get('loss'))
tl_yz_750 = np.array(hf.get('true_loss'))
W_yz_750  = np.array(hf.get('Wout'))
hf.close()

hf       = h5py.File('./data/Lorenz_Rec_x_[0]_750_10050.h5','w')
hf.create_dataset('Wout'     ,data=W_yz_750)
hf.create_dataset('loss'     ,data=nz(l_yz_750))
hf.create_dataset('true_loss',data=nz(tl_yz_750))
hf.close()

hf       = h5py.File('./data/Lorenz_Rec_x_[0]_1000_10050.h5','r')
l_yz_1000  = np.array(hf.get('loss'))
tl_yz_1000 = np.array(hf.get('true_loss'))
W_yz_1000  = np.array(hf.get('Wout'))
hf.close()

hf       = h5py.File('./data/Lorenz_Rec_x_[0]_1000_10050.h5','w')
hf.create_dataset('Wout'     ,data=W_yz_1000)
hf.create_dataset('loss'     ,data=nz(l_yz_1000))
hf.create_dataset('true_loss',data=nz(tl_yz_1000))
hf.close()

hf       = h5py.File('./data/Lorenz_Rec_x_[0]_100_10050_FE.h5','r')
l_yz_100F  = np.array(hf.get('loss'))
tl_yz_100F = np.array(hf.get('true_loss'))
W_yz_100F  = np.array(hf.get('Wout'))
hf.close()

hf       = h5py.File('./data/Lorenz_Rec_x_[0]_100_10050_FE.h5','w')
hf.create_dataset('Wout'     ,data=W_yz_100F)
hf.create_dataset('loss'     ,data=nz(l_yz_100F))
hf.create_dataset('true_loss',data=nz(tl_yz_100F))
hf.close()

hf       = h5py.File('./data/Lorenz_Rec_x_[0]_200_10050_FE.h5','r')
l_yz_200F  = np.array(hf.get('loss'))
tl_yz_200F = np.array(hf.get('true_loss'))
W_yz_200F  = np.array(hf.get('Wout'))
hf.close()

hf       = h5py.File('./data/Lorenz_Rec_x_[0]_200_10050_FE.h5','w')
hf.create_dataset('Wout'     ,data=W_yz_200F)
hf.create_dataset('loss'     ,data=nz(l_yz_200F))
hf.create_dataset('true_loss',data=nz(tl_yz_200F))
hf.close()

hf       = h5py.File('./data/Lorenz_Rec_x_[0]_500_10050_FE.h5','r')
l_yz_500F  = np.array(hf.get('loss'))
tl_yz_500F = np.array(hf.get('true_loss'))
W_yz_500F = np.array(hf.get('Wout'))
hf.close()

hf       = h5py.File('./data/Lorenz_Rec_x_[0]_500_10050_FE.h5','w')
hf.create_dataset('Wout'     ,data=W_yz_500F)
hf.create_dataset('loss'     ,data=nz(l_yz_500F))
hf.create_dataset('true_loss',data=nz(tl_yz_500F))
hf.close()

hf       = h5py.File('./data/Lorenz_Rec_x_[0]_750_10050_FE.h5','r')
l_yz_750F  = np.array(hf.get('loss'))
tl_yz_750F = np.array(hf.get('true_loss'))
W_yz_750F  = np.array(hf.get('Wout'))
hf.close()

hf       = h5py.File('./data/Lorenz_Rec_x_[0]_750_10050_FE.h5','w')
hf.create_dataset('Wout'     ,data=W_yz_750F)
hf.create_dataset('loss'     ,data=nz(l_yz_750F))
hf.create_dataset('true_loss',data=nz(tl_yz_750F))
hf.close()

hf       = h5py.File('./data/Lorenz_Rec_x_[0]_1000_10050_FE.h5','r')
l_yz_1000F  = np.array(hf.get('loss'))
tl_yz_1000F = np.array(hf.get('true_loss'))
W_yz_1000F  = np.array(hf.get('Wout'))
hf.close()

hf       = h5py.File('./data/Lorenz_Rec_x_[0]_1000_10050_FE.h5','w')
hf.create_dataset('Wout'     ,data=W_yz_1000F)
hf.create_dataset('loss'     ,data=nz(l_yz_1000F))
hf.create_dataset('true_loss',data=nz(tl_yz_1000F))
hf.close()
# Out:
# [5.89199121e+03 1.62025378e+03 8.51802490e+02 ... 8.00275803e-02
#  7.39729777e-02 8.00244063e-02]
# [6.34181862e+01 1.42015343e+01 6.53098965e+00 ... 2.30831502e-04
#  2.31003854e-04 2.30844758e-04]
# [10894.90820312  1783.37084961  1004.04870605 ...    33.72352219
#     34.03534698    33.72333908]
# [202.67556763  36.28614426  22.03438187 ...   1.39777124   1.39817667
#    1.39776039]
# [5.41185742e+03 1.06565540e+03 3.93456726e+02 ... 2.03512423e-02
#  1.88791566e-02 2.03497764e-02]
# [5.64791107e+01 9.12024307e+00 2.96790028e+00 ... 1.37187861e-04
#  1.37178620e-04 1.37186056e-04]
# [10033.75976562  1410.34558105   737.27575684 ...    27.37351227
#     27.07664299    27.37321472]
# [166.5695343   26.82559013  16.92212105 ...   1.14775181   1.14890063
#    1.14773881]
# [1.69482266e+04 5.26818237e+02 1.46982132e+02 ... 1.54971266e-02
#  1.35190291e-02 1.54974563e-02]
# [2.63684204e+02 4.00963688e+00 9.10058796e-01 ... 6.05782807e-05
#  6.05479945e-05 6.05757596e-05]
# ...
